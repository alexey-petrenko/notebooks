# %% [markdown]
# ## Interactive Bokeh plot of Elegant Twiss output
#
# <a href=mailto:alexey.petrenko@gmail.com>A. Petrenko</a> (CERN, 2017)

# %% [markdown]
# This notebook explains how to plot <a href=http://www.aps.anl.gov/Accelerator_Systems_Division/Accelerator_Operations_Physics/manuals/elegant_latest/elegant.html>Elegant</a>-produced Twiss-output using <a href=http://bokeh.pydata.org>Bokeh</a> library. The notebook can be executed at the <a href=https://notebooks.azure.com/apetrenko/libraries/SDDS>MS Azure Cloud service</a> (file Twiss_plot.ipynb).
#
# Similar approach can be also used to <a href=https://apetrenko.blob.core.windows.net/fnal-booster-orm/ORM_vs_model.html>plot the MAD-X output</a>.

# %% [markdown]
# First download some sample twiss_output data:

# %%
# Downloading example Elegant twiss_output data:
# !wget -Nq https://apetrenko.blob.core.windows.net/sdds-jupyter/twiss.txt

# %% [markdown]
# This file is the result of this SDDS command
#
# <pre>sdds2stream <a href=https://apetrenko.blob.core.windows.net/sdds-jupyter/twiss.twi>twiss.twi</a> -col=s,ElementName,ElementType,betax,betay,etax > twiss.txt</pre>
#
# applied to the result of twiss_output. Also here is the corresponding <a href=https://apetrenko.blob.core.windows.net/sdds-jupyter/v5_damping_ring.lte>.lte</a> and <a href=https://apetrenko.blob.core.windows.net/sdds-jupyter/twiss.ele>.ele</a> files for details.

# %%
#!head twiss.txt

# %% [markdown]
# Such file is easy to load into the pandas DataFrame for later use:

# %%
import pandas as pd

# %%
df = pd.read_table('twiss.txt', names=['s','ElementName','ElementType','betax','betay','etax'], delim_whitespace=True)

# %%
df.head()
# Out:
#      s ElementName ElementType     betax     betay          etax
# 0  0.0       _BEG_        MARK  4.915917  1.275074  9.063422e-07
# 1  0.0           Q      CHARGE  4.915917  1.275074  9.063422e-07
# 2  0.0          W2        DRIF  4.915917  1.275074  9.063422e-07
# 3  0.0       MA_80      MAXAMP  4.915917  1.275074  9.063422e-07
# 4  0.1        Q3F3        QUAD  4.531497  1.522587  8.679051e-07

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e0399f22-0147-4d76-b964-a77c2e857afb">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Simple plot:

# %%
p = figure(tools="save,box_zoom,pan,reset", toolbar_location="right",
            logo="grey", plot_width=800, plot_height=300, active_drag="box_zoom")

p.line(df.s, df.betax, color='red', line_width=2, line_alpha=0.5, legend='Beta x')
p.line(df.s, df.betay, color='blue', line_width=2, line_alpha=0.5, legend='Beta y')
p.legend.background_fill_alpha = 0.5
p.y_range.start=0; #p.y_range.end = df[['betax','betay']].values.max() + 0.5
p.xaxis.axis_label='s (m)'
p.yaxis.axis_label='Beta x,y (m)'

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="819c1320-7c7d-4510-bf9c-901e05f87052"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("819c1320-7c7d-4510-bf9c-901e05f87052");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("819c1320-7c7d-4510-bf9c-901e05f87052");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '819c1320-7c7d-4510-bf9c-901e05f87052' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"12d25cf4-92c1-4bd8-a913-aaa9f55dfb24":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"1ec4b251-34a4-4937-b71b-69eefcd3a3c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"415efbe4-db28-4573-93f5-b584a88b3990","type":"BasicTicker"}},"id":"e18f0f2f-5280-47e5-8e52-e5fb2e069e4c","type":"Grid"},{"attributes":{"plot":{"id":"1ec4b251-34a4-4937-b71b-69eefcd3a3c1","subtype":"Figure","type":"Plot"}},"id":"3c43ac3f-30fa-499f-9075-f4f6b98c733a","type":"PanTool"},{"attributes":{"plot":{"id":"1ec4b251-34a4-4937-b71b-69eefcd3a3c1","subtype":"Figure","type":"Plot"}},"id":"7c33e781-201a-450c-b96c-cedba2e1f574","type":"ResetTool"},{"attributes":{},"id":"415efbe4-db28-4573-93f5-b584a88b3990","type":"BasicTicker"},{"attributes":{"label":{"value":"Beta y"},"renderers":[{"id":"3d9f6bfa-e34f-4b21-8959-0e1efe6cfca1","type":"GlyphRenderer"}]},"id":"ea68f989-a186-4df1-b4df-4b463deed0f9","type":"LegendItem"},{"attributes":{"active_drag":{"id":"79879579-c955-4a44-ae61-33d28968fa8b","type":"BoxZoomTool"},"active_scroll":"auto","active_tap":"auto","logo":"grey","tools":[{"id":"89a7057a-1c21-4ab6-902b-e9608c74704a","type":"SaveTool"},{"id":"79879579-c955-4a44-ae61-33d28968fa8b","type":"BoxZoomTool"},{"id":"3c43ac3f-30fa-499f-9075-f4f6b98c733a","type":"PanTool"},{"id":"7c33e781-201a-450c-b96c-cedba2e1f574","type":"ResetTool"}]},"id":"3ce0fe5d-d68f-4c1b-9919-229a7d343684","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"64be180e-df38-46de-a5f7-1abba9e7b017","type":"BoxAnnotation"},{"attributes":{"label":{"value":"Beta x"},"renderers":[{"id":"54c78391-0c25-433b-bc70-068c598f4342","type":"GlyphRenderer"}]},"id":"7de06391-0bc9-40d5-8924-9571ae66e5b1","type":"LegendItem"},{"attributes":{"data_source":{"id":"392f5172-80b3-4db9-8187-86a4a2307f91","type":"ColumnDataSource"},"glyph":{"id":"229403d6-104d-48e1-b8c1-c9f377066716","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1136066c-0c89-4b59-bd4e-be70b204bc19","type":"Line"},"selection_glyph":null},"id":"3d9f6bfa-e34f-4b21-8959-0e1efe6cfca1","type":"GlyphRenderer"},{"attributes":{"axis_label":"Beta x,y (m)","formatter":{"id":"22e970d6-8dde-4692-b438-4682e7b68c4a","type":"BasicTickFormatter"},"plot":{"id":"1ec4b251-34a4-4937-b71b-69eefcd3a3c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"415efbe4-db28-4573-93f5-b584a88b3990","type":"BasicTicker"}},"id":"eb532bc9-87e1-4b17-8b26-8ea617310087","type":"LinearAxis"},{"attributes":{"below":[{"id":"6e322cc4-99bb-4015-ad8b-e6f3e5cc9788","type":"LinearAxis"}],"left":[{"id":"eb532bc9-87e1-4b17-8b26-8ea617310087","type":"LinearAxis"}],"plot_height":300,"plot_width":800,"renderers":[{"id":"6e322cc4-99bb-4015-ad8b-e6f3e5cc9788","type":"LinearAxis"},{"id":"144b2f7a-7d9c-4b87-ae50-3d0656b98b5d","type":"Grid"},{"id":"eb532bc9-87e1-4b17-8b26-8ea617310087","type":"LinearAxis"},{"id":"e18f0f2f-5280-47e5-8e52-e5fb2e069e4c","type":"Grid"},{"id":"64be180e-df38-46de-a5f7-1abba9e7b017","type":"BoxAnnotation"},{"id":"e3418868-b1cf-4762-bb91-fcce93d5dd64","type":"Legend"},{"id":"54c78391-0c25-433b-bc70-068c598f4342","type":"GlyphRenderer"},{"id":"3d9f6bfa-e34f-4b21-8959-0e1efe6cfca1","type":"GlyphRenderer"}],"title":{"id":"11484ed1-2411-46af-b503-1c9858f310e0","type":"Title"},"tool_events":{"id":"271f811a-66b2-44c9-a861-d7e2eee29bef","type":"ToolEvents"},"toolbar":{"id":"3ce0fe5d-d68f-4c1b-9919-229a7d343684","type":"Toolbar"},"x_range":{"id":"2308508e-6c1d-48e3-af5d-caebf3bb3da6","type":"DataRange1d"},"y_range":{"id":"cb069665-7dec-4b42-90ec-356ae2daf25c","type":"DataRange1d"}},"id":"1ec4b251-34a4-4937-b71b-69eefcd3a3c1","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"2308508e-6c1d-48e3-af5d- ...

# %% [markdown]
# ## More complicated plot with lattice layout and hover annotations:

# %%
df['L'] = df['s'] - df['s'].shift(+1) # lengths of all elements
df.set_value(0, 'L', 0) # replace NaN with 0 in the first row
df['s0'] = df['s'] - df['L']/2 # centers of all elements
df.head()
# Out:
#      s ElementName ElementType     betax     betay          etax    L    s0
# 0  0.0       _BEG_        MARK  4.915917  1.275074  9.063422e-07  0.0  0.00
# 1  0.0           Q      CHARGE  4.915917  1.275074  9.063422e-07  0.0  0.00
# 2  0.0          W2        DRIF  4.915917  1.275074  9.063422e-07  0.0  0.00
# 3  0.0       MA_80      MAXAMP  4.915917  1.275074  9.063422e-07  0.0  0.00
# 4  0.1        Q3F3        QUAD  4.531497  1.522587  8.679051e-07  0.1  0.05

# %%
from bokeh.models import (HoverTool, ColumnDataSource,
                          CustomJS)
from bokeh.layouts import gridplot

def pic_h(row):
    if row.ElementType.endswith('BEN'): return 4
    if row.ElementType.startswith('SEXT'): return 5
    if row.ElementType.endswith('QUAD'): return 6
    if row.ElementName.startswith('BPM'): return 5
    return 3

def pic_L(row):
    if row.L < 0.01:
        return 0.01
    else:
        return row.L

def pic_color(row):
    if row.ElementType.endswith('BEN'): return 'green'
    if row.ElementType.endswith('SEXT'): return 'yellow'
    if row.ElementType.endswith('QUAD'):
        if row.ElementName[-2] == 'F': return 'red'
        return 'blue'
    if row.ElementName.startswith('BPM'): return 'magenta'
    return 'white'

df["pic_h"] = df.apply(pic_h, axis = 1)
df["pic_L"] = df.apply(pic_L, axis = 1)
df["pic_color"] = df.apply(pic_color, axis = 1)

all_elements_src = ColumnDataSource(data=dict(
    NAME=df.ElementName.values,
    s = df.s0.values,
    L = df.pic_L.values,
    h = df.pic_h.values,
    color = df.pic_color.values,
))

p = figure(tools="save,xbox_zoom,xpan,reset", toolbar_location="above",
            logo="grey", plot_width=800, plot_height=110, active_drag="xbox_zoom",
            y_axis_type=None)

#p.x_range.start = df.s.values.min() - 1
#p.x_range.end   = df.s.values.max() + 1

r1 = p.rect('s', 0, width='L', height='h', fill_color='color',
            fill_alpha=0.5, line_width=1.0, line_alpha=0.2,
            line_color='black', source=all_elements_src)

tips = [
    ('Name', '@NAME'),      
]

hover = HoverTool(tooltips=tips)
p.add_tools(hover)

#hover = p.select_one(HoverTool)
#hover.tooltips = tips

#hover.renderers=[c1,c2,r1,r2]
hover.renderers=[r1]

p.y_range.start = -7
p.y_range.end   = +7
p.xaxis.axis_label='s (m)'

p_layout = p
show(p_layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6e368d6b-49c5-4556-987a-d7825da213bc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6e368d6b-49c5-4556-987a-d7825da213bc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6e368d6b-49c5-4556-987a-d7825da213bc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6e368d6b-49c5-4556-987a-d7825da213bc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6d099469-e745-485a-8736-41ae4b9f7f51":{"roots":{"references":[{"attributes":{"callback":null,"end":7,"start":-7},"id":"d98f67b9-8504-4ce9-aede-7ce60a22f849","type":"DataRange1d"},{"attributes":{"axis_label":"s (m)","formatter":{"id":"7ef0d2f2-f785-4f77-81ea-5903105afb72","type":"BasicTickFormatter"},"plot":{"id":"dd729601-f2bf-4c8b-846a-f0b3810c5f1b","subtype":"Figure","type":"Plot"},"ticker":{"id":"850c4cb8-c3b2-4b2b-a5d6-dc7ca55a597c","type":"BasicTicker"}},"id":"142a34b6-00b5-46b4-8377-eba0f96c5baa","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"18def3ea-8a49-44cf-baa3-7ae6794e84a7","type":"Title"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"height":{"field":"h","units":"data"},"line_alpha":{"value":0.2},"width":{"field":"L","units":"data"},"x":{"field":"s"},"y":{"value":0}},"id":"3e51d7f7-046e-4d5e-8d88-29707d999673","type":"Rect"},{"attributes":{"data_source":{"id":"fb0b7c43-30ab-471d-8506-3c26e44ede92","type":"ColumnDataSource"},"glyph":{"id":"3e51d7f7-046e-4d5e-8d88-29707d999673","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b2854d62-2e35-44f0-8a30-460dfd962a83","type":"Rect"},"selection_glyph":null},"id":"35c8d285-0591-446f-b72b-fc8701de1eb1","type":"GlyphRenderer"},{"attributes":{"dimensions":"width","plot":{"id":"dd729601-f2bf-4c8b-846a-f0b3810c5f1b","subtype":"Figure","type":"Plot"}},"id":"9d60d623-a3e4-4479-af2f-42685c45281e","type":"PanTool"},{"attributes":{},"id":"850c4cb8-c3b2-4b2b-a5d6-dc7ca55a597c","type":"BasicTicker"},{"attributes":{"callback":null,"plot":{"id":"dd729601-f2bf-4c8b-846a-f0b3810c5f1b","subtype":"Figure","type":"Plot"},"renderers":[{"id":"35c8d285-0591-446f-b72b-fc8701de1eb1","type":"GlyphRenderer"}],"tooltips":[["Name","@NAME"]]},"id":"0d0ede01-aa6b-4f18-8a26-1a3fc4836dae","type":"HoverTool"},{"attributes":{},"id":"7ef0d2f2-f785-4f77-81ea-5903105afb72","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"aa5047ee-805a-4ea3-a103-9db15f555725","type":"DataRange1d"},{"attributes":{"plot":{"id":"dd729601-f2bf-4c8b-846a-f0b3810c5f1b","subtype":"Figure","type":"Plot"}},"id":"4eada43c-7345-4c9c-8b81-136cd6beebda","type":"SaveTool"},{"attributes":{"plot":{"id":"dd729601-f2bf-4c8b-846a-f0b3810c5f1b","subtype":"Figure","type":"Plot"},"ticker":{"id":"850c4cb8-c3b2-4b2b-a5d6-dc7ca55a597c","type":"BasicTicker"}},"id":"e292d749-7607-47a4-8298-d3799cecc0dd","type":"Grid"},{"attributes":{"plot":{"id":"dd729601-f2bf-4c8b-846a-f0b3810c5f1b","subtype":"Figure","type":"Plot"}},"id":"4dc6faa7-c2c7-4b14-8e2d-c78a1c4fc67a","type":"ResetTool"},{"attributes":{"active_drag":{"id":"97b301af-ea7b-45c0-8132-344a5814eea0","type":"BoxZoomTool"},"active_scroll":"auto","active_tap":"auto","logo":"grey","tools":[{"id":"4eada43c-7345-4c9c-8b81-136cd6beebda","type":"SaveTool"},{"id":"97b301af-ea7b-45c0-8132-344a5814eea0","type":"BoxZoomTool"},{"id":"9d60d623-a3e4-4479-af2f-42685c45281e","type":"PanTool"},{"id":"4dc6faa7-c2c7-4b14-8e2d-c78a1c4fc67a","type":"ResetTool"},{"id":"0d0ede01-aa6b-4f18-8a26-1a3fc4836dae","type":"HoverTool"}]},"id":"4f066e63-1a37-4fec-9d07-32e5af64a58e","type":"Toolbar"},{"attributes":{},"id":"c9c21086-a709-4d1f-b40a-89f5040cba99","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"field":"h","units":"data"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"field":"L","units":"data"},"x":{"field":"s"},"y":{"value":0}},"id":"b2854d62-2e35-44f0-8a30-460dfd962a83","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2edfb2fb-a36b-45ce-aa5f-4a3e1f976915","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"142a34b6-00b5-46b4-83 ...

# %%
p = figure(tools="save,xbox_zoom,xpan,reset", x_range=p_layout.x_range, toolbar_location="right",
            logo="grey", plot_width=800, plot_height=300, active_drag="xbox_zoom")

p.line(df.s, df.betax, color='red', line_width=2, line_alpha=0.5, legend='Beta x')
p.line(df.s, df.betay, color='blue', line_width=2, line_alpha=0.5, legend='Beta y')
p.legend.background_fill_alpha = 0.5
p.y_range.start=0; #p.y_range.end = df[['betax','betay']].values.max() + 0.5

p.xaxis.major_label_text_alpha = 0
p.xaxis.major_label_text_font_size = '1pt'

p.yaxis.axis_label='Beta x,y (m)'

lay=gridplot([
        [p],
        [p_layout]
            ], toolbar_location='right')
show(lay)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="63dca3cf-0ea2-4826-a56a-f99b74f60c33"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("63dca3cf-0ea2-4826-a56a-f99b74f60c33");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("63dca3cf-0ea2-4826-a56a-f99b74f60c33");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '63dca3cf-0ea2-4826-a56a-f99b74f60c33' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fea6a3bb-9ae1-457e-b8bd-602588d161b2":{"roots":{"references":[{"attributes":{"callback":null,"end":7,"start":-7},"id":"d98f67b9-8504-4ce9-aede-7ce60a22f849","type":"DataRange1d"},{"attributes":{"children":[{"id":"5700e5a2-8529-4dcd-9dc1-74be04aaf2ac","subtype":"Figure","type":"Plot"}]},"id":"682b187b-8f46-49a9-9650-41556cc644a7","type":"Row"},{"attributes":{"plot":null,"text":""},"id":"18def3ea-8a49-44cf-baa3-7ae6794e84a7","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"5700e5a2-8529-4dcd-9dc1-74be04aaf2ac","subtype":"Figure","type":"Plot"},"ticker":{"id":"139cbc41-bdcf-41c4-a0e5-d35c6301ec78","type":"BasicTicker"}},"id":"dc9cad95-02f2-498c-928c-047456b46df8","type":"Grid"},{"attributes":{"below":[{"id":"39acc265-3505-4a8e-9450-fee685e45bd6","type":"LinearAxis"}],"left":[{"id":"5cf4a207-6432-477f-9ca3-6996bffa07de","type":"LinearAxis"}],"plot_height":300,"plot_width":800,"renderers":[{"id":"39acc265-3505-4a8e-9450-fee685e45bd6","type":"LinearAxis"},{"id":"82b827c1-42d9-47a1-bf7d-6631d9c58c3c","type":"Grid"},{"id":"5cf4a207-6432-477f-9ca3-6996bffa07de","type":"LinearAxis"},{"id":"dc9cad95-02f2-498c-928c-047456b46df8","type":"Grid"},{"id":"ebc0df1e-111d-40a0-9897-cf4a4c1e0804","type":"BoxAnnotation"},{"id":"84e0cd19-4a7f-44db-ade1-a4b0a259fc31","type":"Legend"},{"id":"95f83edd-5291-45d5-afd3-8c5d2f17b6f0","type":"GlyphRenderer"},{"id":"a1c86590-f1b6-4622-8bcd-34db49d42ff7","type":"GlyphRenderer"}],"title":{"id":"72de8154-acf4-4919-b3b5-66db113f7add","type":"Title"},"tool_events":{"id":"47357833-790d-49bb-8d46-4da59ae70d68","type":"ToolEvents"},"toolbar":{"id":"0061c4bf-0658-4ff1-a20d-4b2409b25d38","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"aa5047ee-805a-4ea3-a103-9db15f555725","type":"DataRange1d"},"y_range":{"id":"3870aaea-19aa-4446-bb96-16942cba44ad","type":"DataRange1d"}},"id":"5700e5a2-8529-4dcd-9dc1-74be04aaf2ac","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"a2b54e1a-715d-4cc0-b217-2287834194e2","type":"BasicTickFormatter"},"major_label_text_alpha":{"value":0},"major_label_text_font_size":{"value":"1pt"},"plot":{"id":"5700e5a2-8529-4dcd-9dc1-74be04aaf2ac","subtype":"Figure","type":"Plot"},"ticker":{"id":"b9173a7b-0eb1-4384-b7e0-0e345d99a0ff","type":"BasicTicker"}},"id":"39acc265-3505-4a8e-9450-fee685e45bd6","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"49809d06-bfb7-49e7-a0a4-0741c0bb644b","type":"Line"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f1f07ef9-8d2d-451b-98e5-79a9b7e0623d","type":"Line"},{"attributes":{},"id":"b9173a7b-0eb1-4384-b7e0-0e345d99a0ff","type":"BasicTicker"},{"attributes":{},"id":"a2b54e1a-715d-4cc0-b217-2287834194e2","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["color","NAME","h","s","L"],"data":{"L":{"__ndarray__":"...","dtype":"float64","shape":[328]},"NAME":["_BEG_","Q","W2","MA_80","Q3F3","Q3F3","D100","BPM06","Q3D3","Q3D3","DK","MA_KICK","KICK3","KICK3","KICK3","KICK3","KICK3","KICK3","KICK3","KICK3","KICK3","KICK3","Q3D2","Q3D2","MA_60","D220","D220","Q3F2","Q3F2","D77","MA_BEND","BPM07","D103","RM5","RM5","RM5","RM5","RM5","RM5","RM5","RM5","RM5","D105","SZ2","D33","BPM08","D122","SZ1","D70","Q3F4","Q3F4","D70","SZ1","D155","D155","SZ2","D105","RM6","RM6","RM6","RM6","RM6","RM6","RM6","RM6","RM6","D128","BPM09","MA_60","D52","Q3F1","Q3F1","D120","Q3D1","Q3D1","D210","D210","CAV","NOCAV","D210","D210","Q4D1","Q4D1","D120","Q4F1","Q4F1","D84","MA_BEND","BPM10","D96","RM7","RM7","RM7","RM7","RM7","RM7","RM7","RM7","RM7","D105","SZ2","D155","D155","SZ1","D70","Q4F4","Q4F4","D70","SZ1","D122","BPM11","D33","SZ2","D105","RM8","RM8","RM8","RM8","RM8","RM8","RM8","RM8","RM8","D128","BPM12","MA_60","D52","Q4F2","Q4F2","D220","D220","MA_KICK","Q4D2","Q4D2","KICK4","KICK4","KICK4","KICK4"," ...

# %% [markdown]
# Generated <i>p_layout</i> can be similarly attached to any other plot, like dispersion function for example:

# %%
p = figure(tools="save,xbox_zoom,xpan,reset", x_range=p_layout.x_range, toolbar_location="right",
            logo="grey", plot_width=800, plot_height=300, active_drag="xbox_zoom")

p.line(df.s, df.etax, color='green', line_width=2, line_alpha=0.5)
p.y_range.start=-0.05

p.xaxis.major_label_text_alpha = 0
p.xaxis.major_label_text_font_size = '1pt'

p.yaxis.axis_label='Dx (m)'

lay=gridplot([
        [p],
        [p_layout]
            ], toolbar_location='right')
show(lay)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d6f30fe3-7c1f-47c5-a8c1-eec0b3a29a10"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d6f30fe3-7c1f-47c5-a8c1-eec0b3a29a10");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d6f30fe3-7c1f-47c5-a8c1-eec0b3a29a10");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd6f30fe3-7c1f-47c5-a8c1-eec0b3a29a10' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"849e4e1e-9930-4054-b3a1-68ebc4c597f0":{"roots":{"references":[{"attributes":{"callback":null,"end":7,"start":-7},"id":"d98f67b9-8504-4ce9-aede-7ce60a22f849","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"3911d3b1-f9cf-4c21-8865-6b70390c8081","type":"Title"},{"attributes":{"plot":null,"text":""},"id":"18def3ea-8a49-44cf-baa3-7ae6794e84a7","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"d658e4a1-6d52-4b57-b6d7-06265215b754","subtype":"Figure","type":"Plot"},"ticker":{"id":"64a4a071-3d68-4a65-b62d-5e9109e08fcc","type":"BasicTicker"}},"id":"be9ecb2b-c5d9-48fb-bd55-7f1211ef5bbf","type":"Grid"},{"attributes":{"plot":{"id":"d658e4a1-6d52-4b57-b6d7-06265215b754","subtype":"Figure","type":"Plot"}},"id":"dc23e282-892d-429e-88ef-287f8278d63a","type":"SaveTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1cb47a28-6b02-49da-9f5b-99e43dd318c8","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2edfb2fb-a36b-45ce-aa5f-4a3e1f976915","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"height":{"field":"h","units":"data"},"line_alpha":{"value":0.2},"width":{"field":"L","units":"data"},"x":{"field":"s"},"y":{"value":0}},"id":"3e51d7f7-046e-4d5e-8d88-29707d999673","type":"Rect"},{"attributes":{"axis_label":"Dx (m)","formatter":{"id":"a44b7692-a1e3-43d1-bac7-0452b18d14bd","type":"BasicTickFormatter"},"plot":{"id":"d658e4a1-6d52-4b57-b6d7-06265215b754","subtype":"Figure","type":"Plot"},"ticker":{"id":"64a4a071-3d68-4a65-b62d-5e9109e08fcc","type":"BasicTicker"}},"id":"e44a1c06-8d1a-44c0-b2c9-4a3ceec6ec3d","type":"LinearAxis"},{"attributes":{"plot":{"id":"d658e4a1-6d52-4b57-b6d7-06265215b754","subtype":"Figure","type":"Plot"},"ticker":{"id":"dff90da0-f062-4a0a-98c8-3da3addd32d9","type":"BasicTicker"}},"id":"2adf82e0-661c-4aed-8ee5-b8989983e43e","type":"Grid"},{"attributes":{"children":[{"id":"189c1515-2e45-4667-8b9f-de99d2fc0b83","type":"Column"},{"id":"6fe98318-c3ab-437f-b4a4-95e545c05f54","type":"ToolbarBox"}]},"id":"cb7c0ee6-4baf-42f5-b733-516c262d17bb","type":"Row"},{"attributes":{"dimensions":"width","plot":{"id":"dd729601-f2bf-4c8b-846a-f0b3810c5f1b","subtype":"Figure","type":"Plot"}},"id":"9d60d623-a3e4-4479-af2f-42685c45281e","type":"PanTool"},{"attributes":{"callback":null,"start":-0.05},"id":"adcadb4c-3ecd-4b0c-825d-064845e14dae","type":"DataRange1d"},{"attributes":{},"id":"7ef0d2f2-f785-4f77-81ea-5903105afb72","type":"BasicTickFormatter"},{"attributes":{"dimensions":"width","plot":{"id":"d658e4a1-6d52-4b57-b6d7-06265215b754","subtype":"Figure","type":"Plot"}},"id":"18e819a1-2c2d-4be7-a55d-899c1bc1c780","type":"PanTool"},{"attributes":{"formatter":{"id":"617614ce-7981-4e56-b2a9-73ad45f79f3e","type":"BasicTickFormatter"},"major_label_text_alpha":{"value":0},"major_label_text_font_size":{"value":"1pt"},"plot":{"id":"d658e4a1-6d52-4b57-b6d7-06265215b754","subtype":"Figure","type":"Plot"},"ticker":{"id":"dff90da0-f062-4a0a-98c8-3da3addd32d9","type":"BasicTicker"}},"id":"1581cac9-4f56-4d1a-86e0-b4535978fa32","type":"LinearAxis"},{"attributes":{"below":[{"id":"1581cac9-4f56-4d1a-86e0-b4535978fa32","type":"LinearAxis"}],"left":[{"id":"e44a1c06-8d1a-44c0-b2c9-4a3ceec6ec3d","type":"LinearAxis"}],"plot_height":300,"plot_width":800,"renderers":[{"id":"1581cac9-4f56-4d1a-86e0-b4535978fa32","type":"LinearAxis"},{"id":"2adf82e0-661c-4aed-8ee5-b8989983e43e","type":"Grid"},{"id":"e44a1c06-8d1a-44c0-b2c9-4a3ceec6ec3d","type":"LinearAxis"},{"id":"be9ecb2b-c5d9-48fb-bd55-7f1211ef5bbf","type":"Grid"},{"id":"f032d21f-0dfb-479e-97d5-df5fd4f30870","type":"BoxAnnotation"},{"id": ...
